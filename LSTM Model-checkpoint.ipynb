# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data
import yfinance as yf

# %%
df=yf.download('TSLA',start = '2015-01-01',end = '2022-12-31')
df.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#                Volume
# Date
# 2022-12-23  166989700
# 2022-12-27  208643400
# 2022-12-28  221070500
# 2022-12-29  221923300
# 2022-12-30  157777300

# %%
df=df.reset_index()
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2015-01-02  14.858000  14.883333  14.217333  14.620667  14.620667  71466000
# 1 2015-01-05  14.303333  14.433333  13.810667  14.006000  14.006000  80527500
# 2 2015-01-06  14.004000  14.280000  13.614000  14.085333  14.085333  93928500
# 3 2015-01-07  14.223333  14.318667  13.985333  14.063333  14.063333  44526000
# 4 2015-01-08  14.187333  14.253333  14.000667  14.041333  14.041333  51637500

# %%
#removing the date and adj close column from the data frame
df=df.drop(['Date','Adj Close'],axis=1)
df.head()
# Out:
#         Open       High        Low      Close    Volume
# 0  14.858000  14.883333  14.217333  14.620667  71466000
# 1  14.303333  14.433333  13.810667  14.006000  80527500
# 2  14.004000  14.280000  13.614000  14.085333  93928500
# 3  14.223333  14.318667  13.985333  14.063333  44526000
# 4  14.187333  14.253333  14.000667  14.041333  51637500

# %%
#plotting the closing price in a graph
plt.plot(df.Close)

# %%
#calculation the moving average of 100 days 
#main logic : first 100 days have a value and the 101th days will have value of mean of the 100 days
ma100=df.Close.rolling(100).mean()
ma100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 2009    234.019467
# 2010    232.024134
# 2011    230.269534
# 2012    228.583501
# 2013    226.981967
# Name: Close, Length: 2014, dtype: float64

# %%
#plotting the 100 days moving average of the data
plt.plot(ma100)

# %%
#plotting the closing price and 100 days moving average in a graph
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'red')

# %%
#200 days moving average data
ma200=df.Close.rolling(200).mean()
ma200
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 2009    255.097317
# 2010    254.317234
# 2011    253.603501
# 2012    252.876117
# 2013    252.091634
# Name: Close, Length: 2014, dtype: float64

# %%
#plotting 200 days moving average data
plt.plot(ma200)

# %%
#final plotting of all the data i.e normal closing price,100 days ma price and 200 days ma price
plt.plot(df.Close)
plt.plot(ma100,'red')
plt.plot(ma200,'green')

# %%
df.shape
#it means we have 2014 rows and 6 column
# Out:
# (2014, 5)

# %%
#splitting data into training data which will be 70 % of the whole data 
#testing data will be remaining 30 % of the whole data
data_training=pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing=pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])
print(data_training.shape)
print(data_testing.shape)
# Out:
# (1409, 1)
# (605, 1)

# %%
data_training.head()
# Out:
#        Close
# 0  14.620667
# 1  14.006000
# 2  14.085333
# 3  14.063333
# 4  14.041333

# %%
data_testing.head()
# Out:
#            Close
# 1409   96.847336
# 1410   94.571335
# 1411   91.625999
# 1412  103.650665
# 1413  108.066666

# %%
#Now we have to scale down the data to range of 0 and 1 we cannot work with the original data because of some reasons
#reasons=???
#so for this we will be using the minmax scalar
#this whole process is also called data preprocessing
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))

# %%
#converting training data into array format and scaling them down to the range of 0 and 1
data_training_array=scaler.fit_transform(data_training)
print(data_training_array)
# Out:
# [[0.05044921]
#  [0.04429978]
#  [0.04509347]
#  ...
#  [0.89595351]
#  [0.89463296]
#  [0.89767433]]

# %%
plt.plot(data_training_array)

# %%
data_training_array.shape[1]
# Out:
# 1

# %%
#desigining a training model
#x-train will be 100 days data and it will be input 
#y-train will be the outcome or output data of 101th days after prediction
x_train=[]
y_train=[]
for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])
x_train,y_train=np.array(x_train),np.array(y_train)

# %%
x_train.shape
# Out:
# (1309, 100, 1)

# %%
#ML model
from keras.layers import Dense,Dropout,LSTM
from keras.models import Sequential

# %%
#creating neural layers
#activation function = Relu >>>appropriate for time series prediction
model = Sequential()
model.add(LSTM(units=50,activation='relu',return_sequences=True,
              input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))



model.add(LSTM(units=60,activation='relu',return_sequences=True))
model.add(Dropout(0.3))


model.add(LSTM(units=80,activation='relu',return_sequences=True))
model.add(Dropout(0.4))


model.add(LSTM(units=120,activation='relu',return_sequences=True))
model.add(Dropout(0.5))


model.add(Dense(units=1))#connect  all the layers

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 100, 50)           10400
#
#  dropout_4 (Dropout)         (None, 100, 50)           0
#
#  lstm_6 (LSTM)               (None, 100, 60)           26640
#
#  dropout_5 (Dropout)         (None, 100, 60)           0
#
#  lstm_7 (LSTM)               (None, 100, 80)           45120
#
#  dropout_6 (Dropout)         (None, 100, 80)           0
#
#  lstm_8 (LSTM)               (None, 100, 120)          96480
#
#  dropout_7 (Dropout)         (None, 100, 120)          0
#
#  dense (Dense)               (None, 100, 1)            121
#
# =================================================================
# Total params: 178761 (698.29 KB)
# Trainable params: 178761 (698.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#optimizing the model
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 9s 136ms/step - loss: 0.0240
# Epoch 2/50
# 41/41 [==============================] - 5s 130ms/step - loss: 0.0222
# Epoch 3/50
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0221
# Epoch 4/50
# 41/41 [==============================] - 5s 130ms/step - loss: 0.0219
# Epoch 5/50
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0218
# Epoch 6/50
# 41/41 [==============================] - 6s 134ms/step - loss: 0.0219
# Epoch 7/50
# 41/41 [==============================] - 6s 134ms/step - loss: 0.0220
# Epoch 8/50
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0218
# Epoch 9/50
# 41/41 [==============================] - 5s 134ms/step - loss: 0.0218
# Epoch 10/50
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0217
# Epoch 11/50
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0218
# Epoch 12/50
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0217
# Epoch 13/50
# 41/41 [==============================] - 6s 142ms/step - loss: 0.0217
# Epoch 14/50
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0217
# Epoch 15/50
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0217
# Epoch 16/50
# 41/41 [==============================] - 6s 142ms/step - loss: 0.0217
# Epoch 17/50
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0217
# Epoch 18/50
# 41/41 [==============================] - 6s 139ms/step - loss: 0.0217
# Epoch 19/50
# 41/41 [==============================] - 6s 150ms/step - loss: 0.0216
# Epoch 20/50
# 41/41 [==============================] - 6s 145ms/step - loss: 0.0216
# Epoch 21/50
# 41/41 [==============================] - 6s 150ms/step - loss: 0.0216
# Epoch 22/50
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0216
# Epoch 23/50
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0217
# Epoch 24/50
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0217
# Epoch 25/50
# 41/41 [==============================] - 6s 143ms/step - loss: 0.0216
# Epoch 26/50
# 41/41 [==============================] - 6s 143ms/step - loss: 0.0216
# Epoch 27/50
# 41/41 [==============================] - 6s 153ms/step - loss: 0.0216
# Epoch 28/50
# 41/41 [==============================] - 6s 145ms/step - loss: 0.0217
# Epoch 29/50
# 41/41 [==============================] - 6s 146ms/step - loss: 0.0216
# Epoch 30/50
# 41/41 [==============================] - 6s 145ms/step - loss: 0.0216
# Epoch 31/50
# 41/41 [==============================] - 6s 143ms/step - loss: 0.0216
# Epoch 32/50
# 41/41 [==============================] - 6s 150ms/step - loss: 0.0216
# Epoch 33/50
# 41/41 [==============================] - 6s 146ms/step - loss: 0.0216
# Epoch 34/50
# 41/41 [==============================] - 6s 144ms/step - loss: 0.0216
# Epoch 35/50
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0216
# Epoch 36/50
# 41/41 [==============================] - 6s 144ms/step - loss: 0.0216
# Epoch 37/50
# 41/41 [==============================] - 6s 154ms/step - loss: 0.0216
# Epoch 38/50
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0216
# Epoch 39/50
# 41/41 [==============================] - 6s 140ms/step - loss: 0.0216
# Epoch 40/50
# 41/41 [==============================] - 6s 143ms/step - loss: 0.0216
# Epoch 41/50
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0216
# Epoch 42/50
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0216
# Epoch 43/50
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0215
# Epoch 44/50
# 41/41 [==============================] - 6s 144ms/step - loss: 0.0216
# Epoch 45/50
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0216
# Epoch 46/50
# 41/41 [==============================] - 6s 144ms/step - loss: 0.0216
# Epoch 47/50
# 41/41 [==============================] - 6s 143ms/step - loss: 0.0216
# Epoch 48/50
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0216
# Epoch 49/50
# 41/41 [==============================] - 6s 144ms/step - loss: 0.0216
# Epoch 50/50
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0216

# %%
model.save('keras_stock_prediction_model.h5')

# %%
# testing >>>>>>>>>>>>>>>>>>>>>>

# %%
data_testing.head()
# Out:
#            Close
# 1409   96.847336
# 1410   94.571335
# 1411   91.625999
# 1412  103.650665
# 1413  108.066666

# %%
data_training.tail(100)
# Out:
#           Close
# 1309  28.680000
# 1310  24.081333
# 1311  28.509333
# 1312  28.502001
# 1313  28.952667
# ...         ...
# 1404  95.384003
# 1405  99.000000
# 1406  99.133331
# 1407  99.001335
# 1408  99.305336
#
# [100 rows x 1 columns]

# %%
past_100_days=data_training.tail(100)

# %%
#appending the past 100 days data to the data testing array
final_df=pd.concat([past_100_days,data_testing],ignore_index=True)

# %%
final_df.head()
# Out:
#        Close
# 0  28.680000
# 1  24.081333
# 2  28.509333
# 3  28.502001
# 4  28.952667

# %%
#scaling down the testing data array into range of 0 and 1
input_data=scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.18856735],
#        [0.18266927],
#        [0.17503667],
#        [0.20619764],
#        [0.21764135],
#        [0.2227741 ],
#        [0.25472286],
#        [0.26361144],
#        [0.26213261],
#        [0.28343409],
#        [0.29175253],
#        [0.28557114],
#        [0.28715017],
#        [0.30957978],
#        [0.32436471],
#        [0.3199852 ],
#        [0.36804745],
#        [0.34794666],
#        [0.32403647],
#        [0.28916459],
#        [0.29894288],
#        [0.22283284],
#        [0.25399035],
#        [0.25836122],
#        [0.25955327],
#        [0.30006583],
#        [0.32610096],
#        [0.31919049],
#        [0.30335691],
#        [0.31952739],
#        [0.32578134],
#        [0.30404798],
#        [0.26615276],
#        [0.27257085],
#        [0.28945827],
#        [0.30143062],
#        [0.29959073],
#        [0.30817695],
#        [0.32471889],
#        [0.29615276],
#        [0.30530047],
#        [0.29519395],
#        [0.30497223],
#        [0.30550779],
#        [0.31248738],
#        [0.31965697],
#        [0.32341452],
#        [0.33606929],
#        [0.32534081],
#        [0.31738516],
#        [0.3097491 ],
#        [0.30206986],
#        [0.30267453],
#        [0.30539549],
#        [0.30093828],
#        [0.30063595],
#        [0.30443668],
#        [0.28831804],
#        [0.29247295],
#        [0.27278679],
#        [0.28355845],
#        [0.30376292],
#        [0.30124058],
#        [0.31602033],
#        [0.30898895],
#        [0.30148246],
#        [0.29206697],
#        [0.29791495],
#        [0.29327628],
#        [0.2904603 ],
#        [0.29010612],
#        [0.31906095],
#        [0.35795817],
#        [0.36886807],
#        [0.36052369],
#        [0.3883728 ],
#        [0.41733625],
#        [0.43342033],
#        [0.4435787 ],
#        [0.42789197],
#        [0.4427149 ],
#        [0.42894585],
#        [0.45016093],
#        [0.45505005],
#        [0.4919519 ],
#        [0.49896601],
#        [0.45974918],
#        [0.47926258],
#        [0.46450877],
#        [0.49028478],
#        [0.4846009 ],
#        [0.4755482 ],
#        [0.50416613],
#        [0.53794101],
#        [0.49894873],
#        [0.49072531],
#        [0.49559716],
#        [0.50923668],
#        [0.51089519],
#        [0.51288197],
#        [0.53775097],
#        [0.5471578 ],
#        [0.56797557],
#        [0.57258829],
#        [0.59061594],
#        [0.6424962 ],
#        [0.69776256],
#        [0.63830673],
#        [0.67134735],
#        [0.6756405 ],
#        [0.66751202],
#        [0.6512379 ],
#        [0.66712332],
#        [0.6722198 ],
#        [0.6675034 ],
#        [0.66892865],
#        [0.69843635],
#        [0.70041448],
#        [0.68406262],
#        [0.65924538],
#        [0.62305192],
#        [0.66302891],
#        [0.69151722],
#        [0.67588234],
#        [0.67182241],
#        [0.67375735],
#        [0.68342338],
#        [0.67136459],
#        [0.63280431],
#        [0.63871275],
#        [0.64256532],
#        [0.62537557],
#        [0.62704265],
#        [0.61773946],
#        [0.6124875 ],
#        [0.55478524],
#        [0.54125802],
#        [0.57855719],
#        [0.52690153],
#        [0.52109677],
#        [0.55818   ],
#        [0.53054682],
#        [0.50183387],
#        [0.47439935],
#        [0.45410852],
#        [0.42391848],
#        [0.51943826],
#        [0.51467002],
#        [0.5419145 ],
#        [0.53684395],
#        [0.54911865],
#        [0.5222888 ],
#        [0.5438235 ],
#        [0.50179931],
#        [0.5032764 ],
#        [0.51634581],
#        [0.50957357],
#        [0.48202676],
#        [0.49076849],
#        [0.47204115],
#        [0.46563172],
#        [0.48664814],
#        [0.51455772],
#        [0.5092194 ],
#        [0.53452897],
#        [0.53502131],
#        [0.5171837 ],
#        [0.52826636],
#        [0.52240976],
#        [0.54397036],
#        [0.5960925 ],
#        [0.57010051],
#        [0.57581895],
#        [0.57662228],
#        [0.55489754],
#        [0.55866372],
#        [0.58037118],
#        [0.55926839],
#        [0.56765595],
#        [0.57525745],
#        [0.54635447],
#        [0.53742269],
#        [0.52239248],
#        [0.55041436],
#        [0.52921655],
#        [0.51945554],
#        [0.5171578 ],
#        [0.51076561],
#        [0.51839305],
#        [0.48096426],
#        [0.47073682],
#        [0.44714625],
#        [0.43142497],
#        [0.44701667],
#        [0.43586493],
#        [0.43676329],
#        [0.42431584],
#        [0.44445981],
#        [0.43936333],
#        [0.46144225],
#        [0.4599306 ],
#        [0.47240395],
#        [0.48252779],
#        [0.47766453],
#        [0.4765243 ],
#        [0.46030202],
#        [0.43241834],
#        [0.45505871],
#        [0.46031068],
#        [0.45898041],
#        [0.4548255 ],
#        [0.46462106],
#        [0.46442237],
#        [0.47116008],
#        [0.45532649],
#        [0.46008608],
#        [0.47021854],
#        [0.47601468],
#        [0.47387242],
#        [0.4763602 ],
#        [0.50474491],
#        [0.52482842],
#        [0.51796113],
#        [0.53251629],
#        [0.52564038],
#        [0.52472474],
#        [0.52318716],
#        [0.52403371],
#        [0.50734495],
#        [0.49444831],
#        [0.50149697],
#        [0.50507315],
#        [0.52990759],
#        [0.51508465],
#        [0.50198935],
#        [0.49958797],
#        [0.49407689],
#        [0.49580448],
#        [0.50813967],
#        [0.5036392 ],
#        [0.49843046],
#        [0.49335129],
#        [0.50565188],
#        [0.4945606 ],
#        [0.49646099],
#        [0.52269482],
#        [0.5312033 ],
#        [0.55061305],
#        [0.55067351],
#        [0.55169279],
#        [0.55489754],
#        [0.54148262],
#        [0.55414601],
#        [0.55088945],
#        [0.54901501],
#        [0.56147973],
#        [0.55709161],
#        [0.53031356],
#        [0.51264009],
#        [0.53274951],
#        [0.51934324],
#        [0.52520846],
#        [0.54770202],
#        [0.54959374],
#        [0.55193466],
#        [0.54326205],
#        [0.55255662],
#        [0.56896032],
#        [0.57311523],
#        [0.57170722],
#        [0.57023875],
#        [0.57125802],
#        [0.58797268],
#        [0.58879329],
#        [0.58964847],
#        [0.57359033],
#        [0.57940374],
#        [0.58069079],
#        [0.59048636],
#        [0.59148839],
#        [0.5936479 ],
#        [0.56832108],
#        [0.57627677],
#        [0.58712617],
#        [0.58859464],
#        [0.60651864],
#        [0.62117748],
#        [0.60925692],
#        [0.6124962 ],
#        [0.60746022],
#        [0.60723562],
#        [0.61268624],
#        [0.61187421],
#        [0.61374003],
#        [0.62312104],
#        [0.61610685],
#        [0.62167847],
#        [0.63358171],
#        [0.63821167],
#        [0.64446571],
#        [0.66581037],
#        [0.68920228],
#        [0.6841576 ],
#        [0.68547925],
#        [0.70983859],
#        [0.72338305],
#        [0.82287636],
#        [0.81732206],
#        [0.83410588],
#        [0.86794983],
#        [0.89987615],
#        [0.98158365],
#        [0.94997691],
#        [0.98613588],
#        [1.        ],
#        [0.99324505],
#        [0.94215084],
#        [0.82170157],
#        [0.86009783],
#        [0.85626249],
#        [0.83027054],
#        [0.81296849],
#        [0.84867827],
#        [0.87828957],
#        [0.88465583],
#        [0.91979549],
#        [0.9369075 ],
#        [0.89558301],
#        [0.90160374],
#        [0.87216524],
#        [0.91973507],
#        [0.92644684],
#        [0.88346379],
#        [0.87448018],
#        [0.81433332],
#        [0.80918504],
#        [0.84610417],
#        [0.86097028],
#        [0.80468461],
#        [0.81611279],
#        [0.77238683],
#        [0.76556276],
#        [0.78066209],
#        [0.7382751 ],
#        [0.7431556 ],
#        [0.71496963],
#        [0.74830389],
#        [0.80906412],
#        [0.85927717],
#        [0.88254816],
#        [0.87782314],
#        [0.87585363],
#        [0.86216231],
#        [0.85044912],
#        [0.97397349],
#        [0.93061899],
#        [0.8775208 ],
#        [0.85729043],
#        [0.82469038],
#        [0.85160659],
#        [0.85703127],
#        [0.89315568],
#        [0.82866388],
#        [0.84425558],
#        [0.82775686],
#        [0.79764456],
#        [0.79818012],
#        [0.75294255],
#        [0.74093564],
#        [0.73091547],
#        [0.74733645],
#        [0.65377752],
#        [0.66867819],
#        [0.7467404 ],
#        [0.74201537],
#        [0.71991055],
#        [0.70736809],
#        [0.73516544],
#        [0.72136174],
#        [0.73402521],
#        [0.74266323],
#        [0.71895174],
#        [0.68046912],
#        [0.69408278],
#        [0.73439659],
#        [0.73522586],
#        [0.6945924 ],
#        [0.67786046],
#        [0.64723847],
#        [0.59757821],
#        [0.62930588],
#        [0.6371665 ],
#        [0.68947868],
#        [0.68424395],
#        [0.69765026],
#        [0.66257971],
#        [0.66171588],
#        [0.63259695],
#        [0.64971759],
#        [0.67957943],
#        [0.6617245 ],
#        [0.62462403],
#        [0.5995909 ],
#        [0.63027331],
#        [0.66339167],
#        [0.69048929],
#        [0.71967733],
#        [0.73329961],
#        [0.79620199],
#        [0.80063338],
#        [0.81342631],
#        [0.81059305],
#        [0.88073413],
#        [0.88741142],
#        [0.88259134],
#        [0.86843358],
#        [0.87447156],
#        [0.92704289],
#        [0.88023314],
#        [0.84092995],
#        [0.85086375],
#        [0.82342053],
#        [0.78061029],
#        [0.79012946],
#        [0.82072551],
#        [0.78844505],
#        [0.80510787],
#        [0.82571832],
#        [0.78170734],
#        [0.80898638],
#        [0.80576434],
#        [0.79969181],
#        [0.6946529 ],
#        [0.69904965],
#        [0.69559439],
#        [0.68976369],
#        [0.71756105],
#        [0.72301167],
#        [0.76047498],
#        [0.69194048],
#        [0.68534963],
#        [0.61750624],
#        [0.62867526],
#        [0.57162948],
#        [0.56644664],
#        [0.60237235],
#        [0.563311  ],
#        [0.59547917],
#        [0.55073397],
#        [0.55039708],
#        [0.5110766 ],
#        [0.52057845],
#        [0.48020415],
#        [0.5066712 ],
#        [0.54893727],
#        [0.59376886],
#        [0.59258541],
#        [0.5771319 ],
#        [0.60704558],
#        [0.54532653],
#        [0.55507892],
#        [0.55665107],
#        [0.56437349],
#        [0.55877601],
#        [0.53940082],
#        [0.49665965],
#        [0.51001411],
#        [0.54139622],
#        [0.48982696],
#        [0.49931153],
#        [0.55185692],
#        [0.54939508],
#        [0.54676048],
#        [0.57432454],
#        [0.57228596],
#        [0.54052377],
#        [0.52970893],
#        [0.51930002],
#        [0.52653011],
#        [0.54156898],
#        [0.53811377],
#        [0.57130986],
#        [0.5874285 ],
#        [0.54487738],
#        [0.54157764],
#        [0.55186555],
#        [0.55516532],
#        [0.55970893],
#        [0.5609528 ],
#        [0.57386672],
#        [0.57897183],
#        [0.64170149],
#        [0.64309226],
#        [0.63321887],
#        [0.60841033],
#        [0.64976947],
#        [0.66552527],
#        [0.70763586],
#        [0.70796414],
#        [0.71654174],
#        [0.73418931],
#        [0.73739402],
#        [0.68436495],
#        [0.69020427],
#        [0.67183111],
#        [0.70039716],
#        [0.68037414],
#        [0.71509917],
#        [0.73917349],
#        [0.73202976],
#        [0.72537849],
#        [0.72245879],
#        [0.70638333],
#        [0.68888262],
#        [0.70583054],
#        [0.7074977 ],
#        [0.70483716],
#        [0.6841576 ],
#        [0.67568368],
#        [0.65723277],
#        [0.65181663],
#        [0.65583338],
#        [0.63782298],
#        [0.64873291],
#        [0.6727813 ],
#        [0.68718959],
#        [0.71419216],
#        [0.72647554],
#        [0.69462696],
#        [0.721785  ],
#        [0.72473926],
#        [0.72370271],
#        [0.73852564],
#        [0.73764456],
#        [0.71709453],
#        [0.68545331],
#        [0.65109104],
#        [0.65285326],
#        [0.67081179],
#        [0.683432  ],
#        [0.63264013],
#        [0.62496955],
#        [0.56575556],
#        [0.58399919],
#        [0.56163521],
#        [0.55469022],
#        [0.51566343],
#        [0.51537837],
#        [0.49863778],
#        [0.50055544],
#        [0.512165  ],
#        [0.46881053],
#        [0.50602334],
#        [0.50820012],
#        [0.51299423],
#        [0.47474487],
#        [0.49329945],
#        [0.48503281],
#        [0.51397898],
#        [0.51973194],
#        [0.52089807],
#        [0.52978667],
#        [0.52724705],
#        [0.52797268],
#        [0.4946988 ],
#        [0.49555398],
#        [0.47523725],
#        [0.44831238],
#        [0.43333397],
#        [0.39780557],
#        [0.43183094],
#        [0.4454359 ],
#        [0.43242696],
#        [0.44141919],
#        [0.42198354],
#        [0.41226571],
#        [0.40454328],
#        [0.37261696],
#        [0.37790348],
#        [0.41234345],
#        [0.41146237],
#        [0.41161785],
#        [0.40620179],
#        [0.44214479],
#        [0.44214479],
#        [0.44255943],
#        [0.41039988],
#        [0.40358447],
#        [0.38860602],
#        [0.38705119],
#        [0.40158907],
#        [0.37248742],
#        [0.35468433],
#        [0.34392995],
#        [0.34618447],
#        [0.32690429],
#        [0.32597138],
#        [0.29469295],
#        [0.29409693],
#        [0.26242975],
#        [0.25672863],
#        [0.22031916],
#        [0.22967419],
#        [0.25328203],
#        [0.25680637],
#        [0.01191708],
#        [0.        ],
#        [0.01147481],
#        [0.01145581],
#        [0.01262368],
#        [0.02483964],
#        [0.03075671],
#        [0.02884079],
#        [0.02645669],
#        [0.02434381],
#        [0.0281221 ],
#        [0.02079011],
#        [0.01611   ],
#        [0.02052233],
#        [0.02678147],
#        [0.03182784],
#        [0.03241349],
#        [0.03658741],
#        [0.05005416],
#        [0.06023672],
#        [0.06368158],
#        [0.06633865],
#        [0.06783822],
#        [0.06653732],
#        [0.05623384],
#        [0.06407548],
#        [0.05950075],
#        [0.06287306],
#        [0.0755883 ],
#        [0.07046937],
#        [0.07589235],
#        [0.07267381],
#        [0.05875615],
#        [0.06909937],
#        [0.07031216],
#        [0.07279475],
#        [0.07235593],
#        [0.07915927],
#        [0.07775472],
#        [0.07742993],
#        [0.07424249],
#        [0.07637954],
#        [0.07566086],
#        [0.07815899],
#        [0.07718806],
#        [0.07849241],
#        [0.08057246],
#        [0.07872046],
#        [0.07906425],
#        [0.07929921],
#        [0.076808  ],
#        [0.0818509 ],
#        [0.09275214],
#        [0.08989467],
#        [0.09013653],
#        [0.08692662],
#        [0.09060299],
#        [0.10170463],
#        [0.1001066 ],
#        [0.11468421],
#        [0.10566434],
#        [0.09917541],
#        [0.10878439],
#        [0.10726928],
#        [0.10893815],
#        [0.11104066],
#        [0.11051202],
#        [0.10937525],
#        [0.11066404],
#        [0.10359291],
#        [0.10793442],
#        [0.10340115],
#        [0.11197185],
#        [0.12414462],
#        [0.13102397],
#        [0.14640492],
#        [0.17455121],
#        [0.17770929],
#        [0.17356648],
#        [0.1784729 ],
#        [0.20445103],
#        [0.19622931],
#        [0.19963963],
#        [0.20468597],
#        [0.19684779],
#        [0.19688235],
#        [0.22144211],
#        [0.2085472 ],
#        [0.21268829],
#        [0.19899521],
#        [0.18239803],
#        [0.20357858],
#        [0.19267562],
#        [0.19658347],
#        [0.19457598],
#        [0.18477524],
#        [0.19414581],
#        [0.19449132],
#        [0.19414927],
#        [0.19493706]])

# %%
input_data.shape
# Out:
# (705, 1)

# %%
x_test=[]
y_test=[]
for i in range(100,input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i,0])

# %%
#converting into numpy array
x_test,y_test=np.array(x_test),np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (605, 100, 1)
# (605,)

# %%
#making prediction
y_predicted=model.predict(x_test)
# Out:
# 19/19 [==============================] - 1s 32ms/step

# %%
y_predicted.shape
# Out:
# (605, 100, 1)

# %%
y_test
# Out:
# array([0.53775097, 0.5471578 , 0.56797557, 0.57258829, 0.59061594,
#        0.6424962 , 0.69776256, 0.63830673, 0.67134735, 0.6756405 ,
#        0.66751202, 0.6512379 , 0.66712332, 0.6722198 , 0.6675034 ,
#        0.66892865, 0.69843635, 0.70041448, 0.68406262, 0.65924538,
#        0.62305192, 0.66302891, 0.69151722, 0.67588234, 0.67182241,
#        0.67375735, 0.68342338, 0.67136459, 0.63280431, 0.63871275,
#        0.64256532, 0.62537557, 0.62704265, 0.61773946, 0.6124875 ,
#        0.55478524, 0.54125802, 0.57855719, 0.52690153, 0.52109677,
#        0.55818   , 0.53054682, 0.50183387, 0.47439935, 0.45410852,
#        0.42391848, 0.51943826, 0.51467002, 0.5419145 , 0.53684395,
#        0.54911865, 0.5222888 , 0.5438235 , 0.50179931, 0.5032764 ,
#        0.51634581, 0.50957357, 0.48202676, 0.49076849, 0.47204115,
#        0.46563172, 0.48664814, 0.51455772, 0.5092194 , 0.53452897,
#        0.53502131, 0.5171837 , 0.52826636, 0.52240976, 0.54397036,
#        0.5960925 , 0.57010051, 0.57581895, 0.57662228, 0.55489754,
#        0.55866372, 0.58037118, 0.55926839, 0.56765595, 0.57525745,
#        0.54635447, 0.53742269, 0.52239248, 0.55041436, 0.52921655,
#        0.51945554, 0.5171578 , 0.51076561, 0.51839305, 0.48096426,
#        0.47073682, 0.44714625, 0.43142497, 0.44701667, 0.43586493,
#        0.43676329, 0.42431584, 0.44445981, 0.43936333, 0.46144225,
#        0.4599306 , 0.47240395, 0.48252779, 0.47766453, 0.4765243 ,
#        0.46030202, 0.43241834, 0.45505871, 0.46031068, 0.45898041,
#        0.4548255 , 0.46462106, 0.46442237, 0.47116008, 0.45532649,
#        0.46008608, 0.47021854, 0.47601468, 0.47387242, 0.4763602 ,
#        0.50474491, 0.52482842, 0.51796113, 0.53251629, 0.52564038,
#        0.52472474, 0.52318716, 0.52403371, 0.50734495, 0.49444831,
#        0.50149697, 0.50507315, 0.52990759, 0.51508465, 0.50198935,
#        0.49958797, 0.49407689, 0.49580448, 0.50813967, 0.5036392 ,
#        0.49843046, 0.49335129, 0.50565188, 0.4945606 , 0.49646099,
#        0.52269482, 0.5312033 , 0.55061305, 0.55067351, 0.55169279,
#        0.55489754, 0.54148262, 0.55414601, 0.55088945, 0.54901501,
#        0.56147973, 0.55709161, 0.53031356, 0.51264009, 0.53274951,
#        0.51934324, 0.52520846, 0.54770202, 0.54959374, 0.55193466,
#        0.54326205, 0.55255662, 0.56896032, 0.57311523, 0.57170722,
#        0.57023875, 0.57125802, 0.58797268, 0.58879329, 0.58964847,
#        0.57359033, 0.57940374, 0.58069079, 0.59048636, 0.59148839,
#        0.5936479 , 0.56832108, 0.57627677, 0.58712617, 0.58859464,
#        0.60651864, 0.62117748, 0.60925692, 0.6124962 , 0.60746022,
#        0.60723562, 0.61268624, 0.61187421, 0.61374003, 0.62312104,
#        0.61610685, 0.62167847, 0.63358171, 0.63821167, 0.64446571,
#        0.66581037, 0.68920228, 0.6841576 , 0.68547925, 0.70983859,
#        0.72338305, 0.82287636, 0.81732206, 0.83410588, 0.86794983,
#        0.89987615, 0.98158365, 0.94997691, 0.98613588, 1.        ,
#        0.99324505, 0.94215084, 0.82170157, 0.86009783, 0.85626249,
#        0.83027054, 0.81296849, 0.84867827, 0.87828957, 0.88465583,
#        0.91979549, 0.9369075 , 0.89558301, 0.90160374, 0.87216524,
#        0.91973507, 0.92644684, 0.88346379, 0.87448018, 0.81433332,
#        0.80918504, 0.84610417, 0.86097028, 0.80468461, 0.81611279,
#        0.77238683, 0.76556276, 0.78066209, 0.7382751 , 0.7431556 ,
#        0.71496963, 0.74830389, 0.80906412, 0.85927717, 0.88254816,
#        0.87782314, 0.87585363, 0.86216231, 0.85044912, 0.97397349,
#        0.93061899, 0.8775208 , 0.85729043, 0.82469038, 0.85160659,
#        0.85703127, 0.89315568, 0.82866388, 0.84425558, 0.82775686,
#        0.79764456, 0.79818012, 0.75294255, 0.74093564, 0.73091547,
#        0.74733645, 0.65377752, 0.66867819, 0.7467404 , 0.74201537,
#        0.71991055, 0.70736809, 0.73516544, 0.72136174, 0.73402521,
#        0.74266323, 0.71895174, 0.68046912, 0.69408278, 0.73439659,
#        0.73522586, 0.6945924 , 0.67786046, 0.64723847, 0.59757821,
#        0.62930588, 0.6371665 , 0.68947868, 0.68424395, 0.69765026,
#        0.66257971, 0.66171588, 0.63259695, 0.64971759, 0.67957943,
#        0.6617245 , 0.62462403, 0.5995909 , 0.63027331, 0.66339167,
#        0.69048929, 0.71967733, 0.73329961, 0.79620199, 0.80063338,
#        0.81342631, 0.81059305, 0.88073413, 0.88741142, 0.88259134,
#        0.86843358, 0.87447156, 0.92704289, 0.88023314, 0.84092995,
#        0.85086375, 0.82342053, 0.78061029, 0.79012946, 0.82072551,
#        0.78844505, 0.80510787, 0.82571832, 0.78170734, 0.80898638,
#        0.80576434, 0.79969181, 0.6946529 , 0.69904965, 0.69559439,
#        0.68976369, 0.71756105, 0.72301167, 0.76047498, 0.69194048,
#        0.68534963, 0.61750624, 0.62867526, 0.57162948, 0.56644664,
#        0.60237235, 0.563311  , 0.59547917, 0.55073397, 0.55039708,
#        0.5110766 , 0.52057845, 0.48020415, 0.5066712 , 0.54893727,
#        0.59376886, 0.59258541, 0.5771319 , 0.60704558, 0.54532653,
#        0.55507892, 0.55665107, 0.56437349, 0.55877601, 0.53940082,
#        0.49665965, 0.51001411, 0.54139622, 0.48982696, 0.49931153,
#        0.55185692, 0.54939508, 0.54676048, 0.57432454, 0.57228596,
#        0.54052377, 0.52970893, 0.51930002, 0.52653011, 0.54156898,
#        0.53811377, 0.57130986, 0.5874285 , 0.54487738, 0.54157764,
#        0.55186555, 0.55516532, 0.55970893, 0.5609528 , 0.57386672,
#        0.57897183, 0.64170149, 0.64309226, 0.63321887, 0.60841033,
#        0.64976947, 0.66552527, 0.70763586, 0.70796414, 0.71654174,
#        0.73418931, 0.73739402, 0.68436495, 0.69020427, 0.67183111,
#        0.70039716, 0.68037414, 0.71509917, 0.73917349, 0.73202976,
#        0.72537849, 0.72245879, 0.70638333, 0.68888262, 0.70583054,
#        0.7074977 , 0.70483716, 0.6841576 , 0.67568368, 0.65723277,
#        0.65181663, 0.65583338, 0.63782298, 0.64873291, 0.6727813 ,
#        0.68718959, 0.71419216, 0.72647554, 0.69462696, 0.721785  ,
#        0.72473926, 0.72370271, 0.73852564, 0.73764456, 0.71709453,
#        0.68545331, 0.65109104, 0.65285326, 0.67081179, 0.683432  ,
#        0.63264013, 0.62496955, 0.56575556, 0.58399919, 0.56163521,
#        0.55469022, 0.51566343, 0.51537837, 0.49863778, 0.50055544,
#        0.512165  , 0.46881053, 0.50602334, 0.50820012, 0.51299423,
#        0.47474487, 0.49329945, 0.48503281, 0.51397898, 0.51973194,
#        0.52089807, 0.52978667, 0.52724705, 0.52797268, 0.4946988 ,
#        0.49555398, 0.47523725, 0.44831238, 0.43333397, 0.39780557,
#        0.43183094, 0.4454359 , 0.43242696, 0.44141919, 0.42198354,
#        0.41226571, 0.40454328, 0.37261696, 0.37790348, 0.41234345,
#        0.41146237, 0.41161785, 0.40620179, 0.44214479, 0.44214479,
#        0.44255943, 0.41039988, 0.40358447, 0.38860602, 0.38705119,
#        0.40158907, 0.37248742, 0.35468433, 0.34392995, 0.34618447,
#        0.32690429, 0.32597138, 0.29469295, 0.29409693, 0.26242975,
#        0.25672863, 0.22031916, 0.22967419, 0.25328203, 0.25680637,
#        0.01191708, 0.        , 0.01147481, 0.01145581, 0.01262368,
#        0.02483964, 0.03075671, 0.02884079, 0.02645669, 0.02434381,
#        0.0281221 , 0.02079011, 0.01611   , 0.02052233, 0.02678147,
#        0.03182784, 0.03241349, 0.03658741, 0.05005416, 0.06023672,
#        0.06368158, 0.06633865, 0.06783822, 0.06653732, 0.05623384,
#        0.06407548, 0.05950075, 0.06287306, 0.0755883 , 0.07046937,
#        0.07589235, 0.07267381, 0.05875615, 0.06909937, 0.07031216,
#        0.07279475, 0.07235593, 0.07915927, 0.07775472, 0.07742993,
#        0.07424249, 0.07637954, 0.07566086, 0.07815899, 0.07718806,
#        0.07849241, 0.08057246, 0.07872046, 0.07906425, 0.07929921,
#        0.076808  , 0.0818509 , 0.09275214, 0.08989467, 0.09013653,
#        0.08692662, 0.09060299, 0.10170463, 0.1001066 , 0.11468421,
#        0.10566434, 0.09917541, 0.10878439, 0.10726928, 0.10893815,
#        0.11104066, 0.11051202, 0.10937525, 0.11066404, 0.10359291,
#        0.10793442, 0.10340115, 0.11197185, 0.12414462, 0.13102397,
#        0.14640492, 0.17455121, 0.17770929, 0.17356648, 0.1784729 ,
#        0.20445103, 0.19622931, 0.19963963, 0.20468597, 0.19684779,
#        0.19688235, 0.22144211, 0.2085472 , 0.21268829, 0.19899521,
#        0.18239803, 0.20357858, 0.19267562, 0.19658347, 0.19457598,
#        0.18477524, 0.19414581, 0.19449132, 0.19414927, 0.19493706])

# %%
y_predicted[1]
y_predicted.shape
# Out:
# (605, 100, 1)

# %%
scaler.scale_ #for determinit the scale factor through which we have previously scaled it down
# Out:
# array([0.00259142])

# %%
scale_factor=1/0.00259142

# %%
y_predicted=y_predicted * scale_factor
y_test=y_test*scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test,'blue',label='Original Price')
plt.plot(y_predicted,'red',label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19516\1642544611.py in <module>
#       1 plt.figure(figsize=(12,6))
#       2 plt.plot(y_test,'blue',label='Original Price')
# ----> 3 plt.plot(y_predicted,'red',label='Predicted Price')
#       4 plt.xlabel('Time')
#       5 plt.ylabel('Price')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
# --> 501             raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                              f"shapes {x.shape} and {y.shape}")
#     503         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2D, but have shapes (605,) and (605, 100, 1)
